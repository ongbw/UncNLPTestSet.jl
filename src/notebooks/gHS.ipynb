# %%
using UncNLPTestSet
function gHS(nlp, x, S)
	b = Int((size(S, 2) + 1)/2)
	g, Y1 = gAD(nlp, nlp.x0, S[:, 1:b])
	g, Y2 = gAD(nlp, nlp.x0, [S[:, b+1:2b-1] g])
	return g, Y2[:, b], [Y1 Y2[:, 1:b-1]] 
end
# Out:
# gHS (generic function with 1 method)

# %%
nlp = SelectProgram("SROSENBR")
# Out:
# UncNLPTestSet.UncProgram("SROSENBR", UncNLPTestSet.var"#403#404"(), UncNLPTestSet.var"#405#406"(), UncNLPTestSet.var"#407#408"(), UncNLPTestSet.var"#409#411"(), 5000, [1.2, 1.0, 1.2, 1.0, 1.2, 1.0, 1.2, 1.0, 1.2, 1.0  …  1.2, 1.0, 1.2, 1.0, 1.2, 1.0, 1.2, 1.0, 1.2, 1.0])

# %%
using LinearAlgebra
S = rand(nlp.n, 32-1);

# %%
g, h, Y = gHS(nlp, nlp.x0, S)
# Out:
# ([211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [0.03925411959641978 0.9716689600390638 … 0.26605731960316614 0.5244171223146084; 0.4724402053591559 0.7158288611754227 … 0.057778745234769335 0.06539657206310001; … ; 0.5825688841901522 
# ...

# %%
# compute [∇f_0, (J∇f_0), Y_0] = gHS(x_0, S_0)
g, Y1 = gAD(nlp, nlp.x0, S[:, 1:b])
# Out:
# UndefVarError: b not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
g2, Y2 = gAD(nlp, nlp.x0, [S[:, b+1:2b-1] g])
# Out:
# ([211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [0.7487123308072052 0.7073758354624657 … 0.4965379069355418 211.59999999999997; 0.1753506639005309 0.0944796006244244 … 0.47396825611335336 -87.99999999999999; … ; 0.7644384737378858 0.12399735589417338 … 0.2101286365631383 211.59999999999997; 0.5663744845360581 0.6432026388862484 … 0.9225269261601554 -87.99999999999999])

# %%
Y = [Y1 Y2[:, 1:b-1]]
# Out:
# 5000×31 Matrix{Float64}:
#  0.517938   0.329162    0.0393085  …  0.329461    0.313232  0.496538
#  0.0336511  0.7468      0.0459114     0.275659    0.398205  0.473968
#  0.757392   0.877309    0.458726      0.537388    0.618723  0.110922
#  0.904563   0.751242    0.874974      0.930838    0.874158  0.860606
#  0.492935   0.680027    0.512544      0.962065    0.79242   0.217686
#  0.447968   0.937085    0.199804   …  0.882039    0.507142  0.197758
#  0.863675   0.592192    0.343657      0.448726    0.185566  0.939086
#  0.619667   0.578846    0.194276      0.00468762  0.936675  0.243613
#  0.0735878  0.0627922   0.897629      0.10743     0.584884  0.564657
#  0.393148   0.0886356   0.291558      0.246905    0.165602  0.435282
#  0.935607   0.660833    0.284331   …  0.333533    0.359908  0.223811
#  0.040327   0.884243    0.682856      0.972976    0.824311  0.411919
#  0.0275094  0.2756      0.712284      0.282411    0.354945  0.852517
# ...

# %%
b = Int((size(S, 2) + 1)/2)
# Out:
# 16

# %%
g, Y1 = gAD(nlp, nlp.x0, S[:, 1:b])
# Out:
# ([211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [0.5179382292509545 0.3291624001344535 … 0.04811125065566135 0.09224306781889369; 0.03365114965353144 0.7468001627221124 … 0.5113927556040558 0.02921231398084001; … ; 0.631904205892639 0.002830355843272958 … 0.16068608299636322 0.6455488644481655; 0.4779680492145213 0.03518757608742007 … 0.33738508660714994 0.11022254167176837])

# %%
g, Y2 = gAD(nlp, nlp.x0, [S[:, b+1:2b-1] g])
# Out:
# ([211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [0.7487123308072052 0.7073758354624657 … 0.4965379069355418 211.59999999999997; 0.1753506639005309 0.0944796006244244 … 0.47396825611335336 -87.99999999999999; … ; 0.7644384737378858 0.12399735589417338 … 0.2101286365631383 211.59999999999997; 0.5663744845360581 0.6432026388862484 … 0.9225269261601554 -87.99999999999999])

# %%
g, Y2[:, b], [Y1 Y2[:, 1:b-1]]
# Out:
# ([211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999  …  211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999, 211.59999999999997, -87.99999999999999], [0.5179382292509545 0.3291624001344535 … 0.31323230816936154 0.4965379069355418; 0.03365114965353144 0.7468001627221124 … 0.3982053221835211 0.47396825611335336; … ; 0.631904205892639 0.0
# ...

# %%
# Out:
# 5000×31 Matrix{Float64}:
#  0.517938   0.329162    0.0393085  …  0.329461    0.313232  0.496538
#  0.0336511  0.7468      0.0459114     0.275659    0.398205  0.473968
#  0.757392   0.877309    0.458726      0.537388    0.618723  0.110922
#  0.904563   0.751242    0.874974      0.930838    0.874158  0.860606
#  0.492935   0.680027    0.512544      0.962065    0.79242   0.217686
#  0.447968   0.937085    0.199804   …  0.882039    0.507142  0.197758
#  0.863675   0.592192    0.343657      0.448726    0.185566  0.939086
#  0.619667   0.578846    0.194276      0.00468762  0.936675  0.243613
#  0.0735878  0.0627922   0.897629      0.10743     0.584884  0.564657
#  0.393148   0.0886356   0.291558      0.246905    0.165602  0.435282
#  0.935607   0.660833    0.284331   …  0.333533    0.359908  0.223811
#  0.040327   0.884243    0.682856      0.972976    0.824311  0.411919
#  0.0275094  0.2756      0.712284      0.282411    0.354945  0.852517
# ...
